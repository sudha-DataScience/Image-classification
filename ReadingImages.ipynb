# %%
import os,sys
import matplotlib.image as mpi

# %%
# elephant = mpi.imread('elephant.jpg')
elephant = mpi.imread('messi.jpg')
print (elephant.shape)
# Out:
# (475, 634, 3)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.xticks([])
plt.yticks([])
plt.imshow(elephant)

# %%
plt.gray()
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(elephant[:,:,0])
plt.subplot(1,3,2)
plt.imshow(elephant[:,:,1])
plt.subplot(1,3,3)
plt.imshow(elephant[:,:,2])
